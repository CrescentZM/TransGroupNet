# %%
import h5py
import matplotlib.pyplot as plt

# 读取HDF5文件
with h5py.File('D:\StudyFiles\PycharmFiles\OnlineResources\GithubRepository\TransGroupNet\dataset\cfo.hdf5', 'r') as f:
    # 数据集名称
    print('数据集名称展示：', list(f.keys()))  # 显示顶层组名

    # 读取数据集
    for i, k in enumerate(list(f.keys())):
        print(f'数据集{i}：', k)
        print(f'数据集{i}形状：', f[k].shape)
        print(f'数据集{i}数据类型', f[k].dtype)
        print(f'数据集{i}属性：', dict(f[k].attrs))
        print('-' * 50)  # 分隔线，使输出更清晰
# Out:
# 数据集名称展示： ['X', 'cfo', 'mod', 'snr', 'sps', 'sro']
# 数据集1： X
# 数据集1形状： (500000, 2, 1024)
# 数据集1数据类型 float32
# 数据集1属性： {}
# 数据集1： X
# 数据集1形状： (500000, 2, 1024)
# 数据集1数据类型 float32
# 数据集1属性： {}
# 数据集1： X
# 数据集1形状： (500000, 2, 1024)
# 数据集1数据类型 float32
# 数据集1属性： {}
# 数据集1： X
# 数据集1形状： (500000, 2, 1024)
# 数据集1数据类型 float32
# 数据集1属性： {}
# 数据集1： X
# 数据集1形状： (500000, 2, 1024)
# 数据集1数据类型 float32
# 数据集1属性： {}
# 数据集1： X
# 数据集1形状： (500000, 2, 1024)
# 数据集1数据类型 float32
# 数据集1属性： {}
